# %% [markdown]
# https://www.kdnuggets.com/5-useful-diy-python-functions-for-parsing-dates-and-times
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# https://docs.python.org/3/library/datetime.html

# %% [markdown]
# https://github.com/balapriyac/python-basics/tree/main/DIY-python-funcs/datetime-parsing
