# %% [markdown]
# https://www.kdnuggets.com/the-essential-guide-to-regular-expressions-for-data-scientists

# %%
import re

# %%
text = "Data science is cool as you get to work with real-world data"
matches = re.findall(r"data", text)
print(matches)
# Out:
# ['data']

# %%
text = "Data science is cool as you get to work with real-world data"
matches = re.findall(r"data", text, re.IGNORECASE)
print(matches)
# Out:
# ['Data', 'data']

# %%
test = "Yaswanth alam is an network automation engineer and learning python"
hi = re.findall(r'network', test)
print(test)
print(hi)
# Out:
# Yaswanth alam is an network automation engineer and learning python
# ['network']

# %%
test = "Yaswanth alam is an network automation engineer and learning python Network"
hi = re.findall(r'network', test)
print(test)
print(hi)
# Out:
# Yaswanth alam is an network automation engineer and learning python Network
# ['network']

# %%
test = "Yaswanth alam is an network automation engineer and learning python Network"
hi = re.findall(r'network', test , re.IGNORECASE)
print(test)
print(hi)
# Out:
# Yaswanth alam is an network automation engineer and learning python Network
# ['network', 'Network']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = "The cat sat on the mat. The bat flew over the rat."
pattern = r"The ... "
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['The cat ', 'The bat ']

# %%
test1 = "The cat sat on the mat. the bat flew over the rat on it."
pattern = r"The ..."
matches = re.findall(pattern, test1)
print(matches)
# Out:
# ['The cat']

# %%
test1 = "The cat sat on the mat. The bat flew over the rat on it."
pattern = r"The ..."
matches = re.findall(pattern, test1)
print(matches)
# Out:
# ['The cat', 'The bat']

# %%
test1 = "The cat sat on the mat. The bat flew over the rat on it."
pattern = r"The ......"
matches = re.findall(pattern, test1)
print(matches)
# Out:
# ['The cat sa', 'The bat fl']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = "The cat sat on the mat. The bat flew over the rat."
pattern = r"[cb]at"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['cat', 'bat']

# %%
text = "The cat sat on the mat. The bat flew over the rat."
pattern = r"[cbr]at"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['cat', 'bat', 'rat']

# %%
text = "The cat sat on the mat. The bat flew over the rat."
pattern = r"[cbrsm]at"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['cat', 'sat', 'mat', 'bat', 'rat']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Find all lowercase words that start with a-d
pattern = r"\b[a-d][a-z]*\b"
text = "apple banana cherry date elephant fig grape kiwi lemon mango orange"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['apple', 'banana', 'cherry', 'date']

# %%
# Find all lowercase words that start with a-d
pattern = r"\b[a-d][a-z]*\b"
text = "apple banana cherry date elephant fig grape kiwi lemon mango orange"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['apple', 'banana', 'cherry', 'date']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = "Phone numbers: 555-1234, 555-5678, 5551234"
pattern = r"\b\d{3}-?\d{4}\b"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['555-1234', '555-5678', '5551234']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = "Phone numbers: 555-1234, 555-5678, 5551"
pattern = r"\b\d{3}-?\d{4}\b"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['555-1234', '555-5678']

# %%
text = "Phone numbers: 555-1234, 555-5678, 5551, 4564743"
pattern = r"\b\d{3}-?\d{4}\b"
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['555-1234', '555-5678', '4564743']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = "Python is popular in data science."

# ^ anchors to the start of the string
start_matches = re.findall(r"^Python", text)
print(start_matches)

# $ anchors to the end of the string
end_matches = re.findall(r"science\.$", text)
print(end_matches)
# Out:
# ['Python']
# ['science.']

# %%
text = "python is popular in data science"

start_matches = re.findall(r"^Python", text)
print(start_matches)

end_matches = re.findall(r"science\.$", text)
print(end_matches)
# Out:
# []
# []

# %%
text = "Python is popular in data science"

start_matches = re.findall(r"^Python", text)
print(start_matches)

end_matches = re.findall(r"science\.$", text)
print(end_matches)
# Out:
# ['Python']
# []

# %%
text = "Python is popular in data science"

start_matches = re.findall(r"^Python", text)
print(start_matches)

end_matches = re.findall(r"science$", text)
print(end_matches)
# Out:
# ['Python']
# ['science']

# %%
text = "Python is popular in data science." 

start_matches = re.findall(r"^Python", text)
print(start_matches)

end_matches = re.findall(r"science\.$", text)
print(end_matches)
# Out:
# ['Python']
# ['science.']

# %%
text = "Yaswanth is an network engineer and also does automation both." 

start_matches = re.findall(r"^Yaswanth", text)
print(start_matches)

end_matches = re.findall(r"both\.$", text)
print(end_matches)
# Out:
# ['Yaswanth']
# ['both.']

# %%
text = "Yaswanth is an network engineer and also does automation both." 

start_matches = re.findall(r"^Yaswanth", text)
print(start_matches)

end_matches = re.findall(r"both.$", text)
print(end_matches)
# Out:
# ['Yaswanth']
# ['both.']

# %%
text = "Yaswanth is an network engineer and also does automation both." 

start_matches = re.findall(r"^Yaswanth", text)
print(start_matches)

end_matches = re.findall(r"both$", text)
print(end_matches)
# Out:
# ['Yaswanth']
# []

# %%
text = "Yaswanth is an network engineer and also does automation both." 

start_matches = re.findall(r"^Yaswanth", text)
print(start_matches)

end_matches = re.findall(r"both", text)
print(end_matches)
# Out:
# ['Yaswanth']
# ['both']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re

# %%
text = "Dates: 2023-10-15, 2022-05-22"
pattern = r"(\d{4})-(\d{2})-(\d{2})"

#findall returns tuples of the captured groups 

matches = re.findall(pattern, text)
print(matches)

# you can use these to create structured data 
for year, month, day in matches:
    print(f"Year: {year}, Month: {month}, Day: {day}")
# Out:
# [('2023', '10', '15'), ('2022', '05', '22')]
# Year: 2023, Month: 10, Day: 15
# Year: 2022, Month: 05, Day: 22

# %%
text = "Dates: 2023-10-15, 2022-05-22"
pattern = r"(\d{4})-(\d{2})-(\d{2})"

#findall returns tuples of the captured groups 

matches = re.findall(pattern, text)
print(matches)

# you can use these to create structured data 
for year, month, day in matches:
    print(f"Year: {year}, Month: {month}, Day: {day}")
# Out:
# [('2023', '10', '15'), ('2022', '05', '22')]
# Year: 2023, Month: 10, Day: 15
# Year: 2022, Month: 05, Day: 22

# %%
test = "Dates: 2025-15-20, 2024-05-07"
pattern1 = r"(\d{4})-(\d{2})-(\d{2})"

print(pattern1)

match = re.findall(pattern1, test)
print(match)

for year, month, day in match:
    print(f"Year: {year}, Month: {month}, Day: {day}")
# Out:
# (\d{4})-(\d{2})-(\d{2})
# [('2025', '15', '20'), ('2024', '05', '07')]
# Year: 2025, Month: 15, Day: 20
# Year: 2024, Month: 05, Day: 07

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re

# %%
text = "Contact: john.doe@example.com"
pattern = r"(?P[\w.]+)@(?P[\w.]+)"

match_ = re.search(pattern, text)
if match_:
    print(f"Username: {match.group('username')}")
    print(f"Domain: {match.group('domain')}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 4
#       1 text = "Contact: john.doe@example.com"
#       2 pattern = r"(?P[\w.]+)@(?P[\w.]+)"
# ----> 4 match_ = re.search(pattern, text)
#       5 if match_:
#       6     print(f"Username: {match.group('username')}")
#
# File /usr/local/python/3.12.1/lib/python3.12/re/__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# File /usr/local/python/3.12.1/lib/python3.12/re/__init__.py:307, in _compile(pattern, flags)
#     301     import warnings
#     302     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     303             "as it is an undocumented flag "
#     304             "without an obvious purpose. "
#     305             "Don't use it.",
#     306             DeprecationWarning)
# --> 307 p = _compiler.compile(pattern, flags)
#     308 if flags & DEBUG:
#     309     return p
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_compiler.py:745, in compile(p, flags)
#     743 if isstring(p):
#     744     pattern = p
# --> 745     p = _parser.parse(p, flags)
#     746 else:
#     747     pattern = None
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_parser.py:979, in parse(str, flags, state)
#     976 state.flags = flags
#     977 state.str = str
# --> 979 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     980 p.state.flags = fix_flags(str, p.state.flags)
#     982 if source.next is not None:
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_parser.py:460, in _parse_sub(source, state, verbose, nested)
#     458 start = source.tell()
#     459 while True:
# --> 460     itemsappend(_parse(source, state, verbose, nested + 1,
#     461                        not nested and not items))
#     462     if not sourcematch("|"):
#     463         break
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_parser.py:746, in _parse(source, state, verbose, nested, first)
#     744         if char is None:
#     745             raise source.error("unexpected end of pattern")
# --> 746         raise source.error("unknown extension ?P" + char,
#     747                            len(char) + 2)
#     748 elif char == ":":
#     749     # non-capturing group
#     750     capture = False
#
# error: unknown extension ?P[ at position 1

# %%
text = "Contact: yaswanth.alam@example.com"
pattern = r"(?P[\w.]+)@(?P[\w.]+)"
match_ = re.search(pattern, text)

if match_:
    print(f"Username: {match.group('username')}")
    print(f"Domain: {match.group('domain')}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 3
#       1 text = "Contact: yaswanth.alam@example.com"
#       2 pattern = r"(?P[\w.]+)@(?P[\w.]+)"
# ----> 3 match_ = re.search(pattern, text)
#       5 if match_:
#       6     print(f"Username: {match.group('username')}")
#
# File /usr/local/python/3.12.1/lib/python3.12/re/__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# File /usr/local/python/3.12.1/lib/python3.12/re/__init__.py:307, in _compile(pattern, flags)
#     301     import warnings
#     302     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     303             "as it is an undocumented flag "
#     304             "without an obvious purpose. "
#     305             "Don't use it.",
#     306             DeprecationWarning)
# --> 307 p = _compiler.compile(pattern, flags)
#     308 if flags & DEBUG:
#     309     return p
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_compiler.py:745, in compile(p, flags)
#     743 if isstring(p):
#     744     pattern = p
# --> 745     p = _parser.parse(p, flags)
#     746 else:
#     747     pattern = None
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_parser.py:979, in parse(str, flags, state)
#     976 state.flags = flags
#     977 state.str = str
# --> 979 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     980 p.state.flags = fix_flags(str, p.state.flags)
#     982 if source.next is not None:
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_parser.py:460, in _parse_sub(source, state, verbose, nested)
#     458 start = source.tell()
#     459 while True:
# --> 460     itemsappend(_parse(source, state, verbose, nested + 1,
#     461                        not nested and not items))
#     462     if not sourcematch("|"):
#     463         break
#
# File /usr/local/python/3.12.1/lib/python3.12/re/_parser.py:746, in _parse(source, state, verbose, nested, first)
#     744         if char is None:
#     745             raise source.error("unexpected end of pattern")
# --> 746         raise source.error("unknown extension ?P" + char,
#     747                            len(char) + 2)
#     748 elif char == ":":
#     749     # non-capturing group
#     750     capture = False
#
# error: unknown extension ?P[ at position 1

# %%
text = "Contact: yaswanth.alam@example.com"
#pattern = r"(?P[\w.]+)@(?P[\w.]+)"
pattern = r"(?P<username>[\w.]+)@(?P<domain>[\w.]+)"
match_ = re.search(pattern, text)

if match_:
    print(f"Username: {match_.group('username')}")
    print(f"Domain: {match_.group('domain')}")
# Out:
# Username: yaswanth.alam
# Domain: example.com

# %%
import re

text = "Contact: john.doe@example.com"
pattern = r"(?P<username>[\w.]+)@(?P<domain>[\w.]+)"

match_ = re.search(pattern, text)
if match_:
    print(f"Username: {match_.group('username')}")
    print(f"Domain: {match_.group('domain')}")
# Out:
# Username: john.doe
# Domain: example.com

# %%
text = "Contact: yaswanthalam@123455@example.com"

pattern = r"(?P<username>[\w.]+)@(?P<domain>[\w.]+)"

match_ = re.search(pattern, text)

if match_:
    print(f"username: {match_.group('username')}")
    print(f"Domain: {match_.group('domain')}")
# Out:
# username: yaswanthalam
# Domain: 123455

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
product_codes = [
    "PROD-123",
    "Product 456",
    "prod_789",
    "PR-101",
    "p-202"
]

# %%
cleaned_codes = []
for code in product_codes:
    # Extract just the numeric portion
    match = re.search(r"\d+", code)
    if match:
        cleaned_codes.append(match.group())

print(cleaned_codes)
# Out:
# ['123', '456', '789', '101', '202']

# %%
cleaned_codes = []
for code in product_codes:
    match = re.search(r"\d+", code)
    if match:
        cleaned_codes.append(match.group())

print(cleaned_codes)
# Out:
# ['123', '456', '789', '101', '202']

# %%
cleaned_codes = []
for code in cleaned_codes:
    match = re.search(r"\d+", code)
    if match:
        cleaned_codes.append(match.group())

print(cleaned_codes)
# Out:
# []

# %%
product_codes123 = [
    "PROD-123",
    "Product 456",
    "prod_789",
    "PR-101",
    "p-202",
    "afksfd",
    "4548748",
    "kmsfdks-8748"
]

# %%
cleaned_codes = []
for code in product_codes123:
    # Extract just the numeric portion
    match = re.search(r"\d+", code)
    if match:
        cleaned_codes.append(match.group())

print(cleaned_codes)
# Out:
# ['123', '456', '789', '101', '202', '4548748', '8748']

# %%
cleaned_codes = []

for code in product_codes:
    digits = ""
    for ch in code:
        if ch.isdigit():
            digits += ch
    if digits:
        cleaned_codes.append(digits)

print(cleaned_codes)
# Out:
# ['123', '456', '789', '101', '202']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
log = "Issue #1234 [2025-11-24] Customer reported app crash on iphone 12, ios 15.2"

# %%
# Extract issue number, date, device, and OS version
pattern = r"ISSUE #(\d+) \[(\d{4}-\d{2}-\d{2})\].*?(iPhone \d+).*?(iOS \d+\.\d+)"
match = re.search(pattern, log)

if match:
    issue_num, date, device, ios_version = match.groups()
    print(f"Issue: {issue_num}")
    print(f"Date: {date}")
    print(f"Device: {device}")
    print(f"iOS Version: {ios_version}")

# %%
# Extract issue number, date, device, and OS version
pattern = r"ISSUE #(\d+) \[(\d{4}-\d{2}-\d{2})\].*?(iPhone \d+).*?(iOS \d+\.\d+)"
match = re.search(pattern, log)

if not match:
    issue_num, date, device, ios_version = match.groups()
    print(f"Issue: {issue_num}")
    print(f"Date: {date}")
    print(f"Device: {device}")
    print(f"iOS Version: {ios_version}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 6
#       3 match = re.search(pattern, log)
#       5 if not match:
# ----> 6     issue_num, date, device, ios_version = match.groups()
#       7     print(f"Issue: {issue_num}")
#       8     print(f"Date: {date}")
#
# AttributeError: 'NoneType' object has no attribute 'groups'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def validate_email(email):
    """Validate email format with explanation of what makes it valid or invalid."""
    pattern = r"^[\w.%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$"
    
    if not re.match(pattern, email):
        # Let's check specific issues
        if '@' not in email:
            return False, "Missing @ symbol"
        
        username, domain = email.split('@', 1)
        if not username:
            return False, "Username is empty"
        
        if '.' not in domain:
            return False, "Invalid domain (missing top-level domain)"
        
        return False, "Invalid email format"
    
    return True, "Valid email"

# %%
# Test with different emails
emails = ["user@example.com", "invalid@.com", "no_at_sign.com", "user@example.co.uk"]
for email in emails:
    valid, reason = validate_email(email)
    print(f"{email}: {reason}")
# Out:
# user@example.com: Valid email
# invalid@.com: Invalid email format
# no_at_sign.com: Missing @ symbol
# user@example.co.uk: Valid email

# %%
emails = ["user@example.com", "invalid@.com", "no_at_sign.com", "user@example.co.uk", "@.com"]
for email in emails:
    valid, reason = validate_email(email)
    print(f"{email}: {reason}")
# Out:
# user@example.com: Valid email
# invalid@.com: Invalid email format
# no_at_sign.com: Missing @ symbol
# user@example.co.uk: Valid email
# @.com: Username is empty

# %%
emails = ["user@example.com", "invalid@.com", "no_at_sign.com", "user@example.co.uk", "@.com", ""]
for email in emails:
    valid, reason = validate_email(email)
    print(f"{email}: {reason}")
# Out:
# user@example.com: Valid email
# invalid@.com: Invalid email format
# no_at_sign.com: Missing @ symbol
# user@example.co.uk: Valid email
# @.com: Username is empty
# : Missing @ symbol
