# %% [markdown]
# https://youtu.be/3tyaO-OE0K0?si=dG87N7G9V9PRk6Hb

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

# %%
def brew_tea():
    print("Brewing tea .......")
    time.sleep(1)
    print("tea is ready.......................")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................

# %%
def brew_tea():
    print("Brewing tea .......")
    time.sleep(10)
    print("tea is ready.......................")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................

# %%
def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................

# %%
def brew_tea():
    start_time = time.time()
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    end_time = time.time()
    print(f"Task time: {end_time - start_time} seconds")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.0007712841033936 seconds

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
timer_dec(brew_tea)
# Out:
# <function __main__.timer_dec.<locals>.enhanced_fn()>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
dec_brew_tea = timer_dec(brew_tea)
dec_brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.001488208770752 seconds

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
dec_brew_tea = timer_dec(brew_tea)
brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................
