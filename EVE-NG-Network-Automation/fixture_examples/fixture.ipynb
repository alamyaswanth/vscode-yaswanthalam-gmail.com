# %%
import pytest

@pytest.fixture
def sample_numbers():
    return [1, 2, 3, 4, 5]

# %%
def test_sum(sample_numbers):
    assert sum(sample_numbers) == 15

# %%
@pytest.fixture
def message():
    print("Setup")
    yield "hello"
    print("Teardown")
