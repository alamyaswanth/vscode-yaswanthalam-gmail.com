# %%
import test_tmp_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import test_tmp_path
#
# ModuleNotFoundError: No module named 'test_tmp_path'
