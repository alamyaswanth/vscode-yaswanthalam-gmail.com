# %% [markdown]
# Got it! You want **practical examples of supervised learning algorithms** like **Decision Trees**, **Random Forests**, etc., applied to **networking scenarios**, and how to implement them in **VS Code**. I’ll give you fully runnable **Python examples with scikit-learn**, tailored for networking data.
#
# Let’s go **step by step**.
#
# ---
#
# ## 1️⃣ Setup in VS Code
#
# First, make sure you have Python and required packages:
#
# ```bash
# pip install scikit-learn pandas numpy matplotlib
# ```
#
# Create a folder in VS Code, e.g., `network_ml_lab`, and inside it create `network_ml.py`.
#
# ---
#
# ## 2️⃣ Example Dataset: Networking
#
# For networking, we can use:
#
# * **Features**: `packet_size`, `duration`, `protocol`, `src_port`, `dst_port`
# * **Target**: `traffic_type` (e.g., Normal, Attack)
#
# ```python
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, classification_report
#
# # Sample networking data
# data = {
#     'packet_size': [60, 1500, 200, 500, 50, 1400, 300, 600],
#     'duration': [1, 5, 2, 3, 1, 6, 2, 3],
#     'protocol': [0, 1, 0, 0, 1, 1, 0, 1],  # 0=TCP, 1=UDP
#     'src_port': [1024, 80, 443, 1234, 53, 22, 8080, 161],
#     'dst_port': [80, 1024, 443, 80, 53, 22, 8080, 161],
#     'traffic_type': ['Normal', 'Attack', 'Normal', 'Normal', 'Attack', 'Attack', 'Normal', 'Attack']
# }
#
# df = pd.DataFrame(data)
#
# # Split features and target
# X = df[['packet_size', 'duration', 'protocol', 'src_port', 'dst_port']]
# y = df['traffic_type']
#
# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# ```
#
# ---
#
# ## 3️⃣ Decision Tree Classifier
#
# ```python
# # Decision Tree
# dt_model = DecisionTreeClassifier(max_depth=3, random_state=42)
# dt_model.fit(X_train, y_train)
# y_pred_dt = dt_model.predict(X_test)
#
# print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
# print(classification_report(y_test, y_pred_dt))
# ```
#
# ---
#
# ## 4️⃣ Random Forest Classifier
#
# ```python
# # Random Forest
# rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
# rf_model.fit(X_train, y_train)
# y_pred_rf = rf_model.predict(X_test)
#
# print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
# print(classification_report(y_test, y_pred_rf))
# ```
#
# ---
#
# ## 5️⃣ Other Supervised Learning Algorithms in Networking
#
# ### a) K-Nearest Neighbors (KNN)
#
# ```python
# from sklearn.neighbors import KNeighborsClassifier
#
# knn = KNeighborsClassifier(n_neighbors=3)
# knn.fit(X_train, y_train)
# y_pred_knn = knn.predict(X_test)
#
# print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
# ```
#
# ### b) Support Vector Machine (SVM)
#
# ```python
# from sklearn.svm import SVC
#
# svm_model = SVC(kernel='linear')
# svm_model.fit(X_train, y_train)
# y_pred_svm = svm_model.predict(X_test)
#
# print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
# ```
#
# ---
#
# ## 6️⃣ Notes on Networking Application
#
# * **Traffic Classification**: Predict if traffic is normal or attack (IDS/IPS system).
# * **Bandwidth Prediction**: Regression models could predict bandwidth usage.
# * **Anomaly Detection**: Supervised ML can detect deviations from normal network patterns.
# * **Routing Optimization**: Predict congestion based on traffic features.
#
# ---
#
# ✅ **Pro Tip:** In your VS Code lab, you can expand this by:
#
# * Reading real **pcap or NetFlow data** using `pyshark` or `pandas`.
# * Using **one-hot encoding** for protocol types if more than TCP/UDP.
# * Plotting Decision Tree using `from sklearn.tree import plot_tree`.
#
# ---
#
# If you want, I can make a **full VS Code ready lab** with **synthetic network traffic data**, **all algorithms implemented**, and **plots to visualize trees and feature importance**, so you can just run it.
#
# Do you want me to do that?

# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install scikit-learn pandas numpy matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Sample networking data
data = {
    'packet_size': [60, 1500, 200, 500, 50, 1400, 300, 600],
    'duration': [1, 5, 2, 3, 1, 6, 2, 3],
    'protocol': [0, 1, 0, 0, 1, 1, 0, 1],  # 0=TCP, 1=UDP
    'src_port': [1024, 80, 443, 1234, 53, 22, 8080, 161],
    'dst_port': [80, 1024, 443, 80, 53, 22, 8080, 161],
    'traffic_type': ['Normal', 'Attack', 'Normal', 'Normal', 'Attack', 'Attack', 'Normal', 'Attack']
}

df = pd.DataFrame(data)

# Split features and target
X = df[['packet_size', 'duration', 'protocol', 'src_port', 'dst_port']]
y = df['traffic_type']

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Decision Tree
dt_model = DecisionTreeClassifier(max_depth=3, random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 1.0
#               precision    recall  f1-score   support
#
#       Attack       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %%
# Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 1.0
#               precision    recall  f1-score   support
#
#       Attack       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 1.0

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.5

# %%
print("test")
# Out:
# test
