# %% [markdown]
# https://youtu.be/3tyaO-OE0K0?si=dG87N7G9V9PRk6Hb

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

# %%
def brew_tea():
    print("Brewing tea .......")
    time.sleep(1)
    print("tea is ready.......................")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................

# %%
def brew_tea():
    print("Brewing tea .......")
    time.sleep(10)
    print("tea is ready.......................")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................

# %%
def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................

# %%
def brew_tea():
    start_time = time.time()
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    end_time = time.time()
    print(f"Task time: {end_time - start_time} seconds")

brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.0007712841033936 seconds

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
timer_dec(brew_tea)
# Out:
# <function __main__.timer_dec.<locals>.enhanced_fn()>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
dec_brew_tea = timer_dec(brew_tea)
dec_brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.001488208770752 seconds

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
dec_brew_tea = timer_dec(brew_tea)
brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
brew_tea()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.02350115776062 seconds

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea()
make_matcha()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.001419544219971 seconds
# Making matcha..................
# Matcha is ready!................,,,,,,,,,,,,,,,,
# Task time: 2.0010828971862793 seconds

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea()
make_matcha
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.003937005996704 seconds
# <function __main__.timer_dec.<locals>.enhanced_fn()>

# %%
def timer_dec(base_fn):
    def enhanced_fn():
        start_time = time.time()
        base_fn()
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea():
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea("green" , 1)
make_matcha()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 21
#      18     time.sleep(2)
#      19     print("Matcha is ready!................,,,,,,,,,,,,,,,,")
# ---> 21 brew_tea("green" , 1)
#      22 make_matcha()
#
# TypeError: timer_dec.<locals>.enhanced_fn() takes 0 positional arguments but 2 were given

# %%
def timer_dec(base_fn):
    def enhanced_fn(tea_type , steep_time):
        start_time = time.time()
        base_fn(tea_type , steep_time)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea("green" , 1)
make_matcha()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.001466512680054 seconds
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 22
#      19     print("Matcha is ready!................,,,,,,,,,,,,,,,,")
#      21 brew_tea("green" , 1)
# ---> 22 make_matcha()
#
# TypeError: timer_dec.<locals>.enhanced_fn() missing 2 required positional arguments: 'tea_type' and 'steep_time'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args):
        start_time = time.time()
        base_fn(args)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea("green" , 1)
make_matcha()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 21
#      18     time.sleep(2)
#      19     print("Matcha is ready!................,,,,,,,,,,,,,,,,")
# ---> 21 brew_tea("green" , 1)
#      22 make_matcha()
#
# Cell In[20], line 4, in timer_dec.<locals>.enhanced_fn(*args)
#       2 def enhanced_fn(*args):
#       3     start_time = time.time()
# ----> 4     base_fn(args)
#       5     end_time = time.time()
#       6     print(f"Task time: {end_time - start_time} seconds")
#
# TypeError: brew_tea() missing 1 required positional argument: 'steep_time'

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args):
        start_time = time.time()
        base_fn(*args)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea("green" , 1)
make_matcha()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.001042127609253 seconds
# Making matcha..................
# Matcha is ready!................,,,,,,,,,,,,,,,,
# Task time: 2.000973701477051 seconds

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args):
        start_time = time.time()
        base_fn(*args)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea("green" , 1)
make_matcha()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.001769304275513 seconds
# Making matcha..................
# Matcha is ready!................,,,,,,,,,,,,,,,,
# Task time: 2.0007026195526123 seconds

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args):
        start_time = time.time()
        base_fn(*args)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(*args):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea("green" , 1)
make_matcha()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.001762390136719 seconds
# Making matcha..................
# Matcha is ready!................,,,,,,,,,,,,,,,,
# Task time: 2.0037412643432617 seconds

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args):
        start_time = time.time()
        base_fn(*args)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea(tea_type = "green" , steep_time = 1)
make_matcha()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 21
#      18     time.sleep(2)
#      19     print("Matcha is ready!................,,,,,,,,,,,,,,,,")
# ---> 21 brew_tea(tea_type = "green" , steep_time = 1)
#      22 make_matcha()
#
# TypeError: timer_dec.<locals>.enhanced_fn() got an unexpected keyword argument 'tea_type'

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args , **kwargs):
        start_time = time.time()
        base_fn(*args)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea(tea_type = "green" , steep_time = 1)
make_matcha()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 21
#      18     time.sleep(2)
#      19     print("Matcha is ready!................,,,,,,,,,,,,,,,,")
# ---> 21 brew_tea(tea_type = "green" , steep_time = 1)
#      22 make_matcha()
#
# Cell In[27], line 4, in timer_dec.<locals>.enhanced_fn(*args, **kwargs)
#       2 def enhanced_fn(*args , **kwargs):
#       3     start_time = time.time()
# ----> 4     base_fn(*args)
#       5     end_time = time.time()
#       6     print(f"Task time: {end_time - start_time} seconds")
#
# TypeError: brew_tea() missing 2 required positional arguments: 'tea_type' and 'steep_time'

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args , **kwargs):
        start_time = time.time()
        base_fn(*args , **kwargs)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")

brew_tea(tea_type = "green" , steep_time = 1)
make_matcha()
# Out:
# Brewing tea .......
# tea is ready.......................
# Task time: 5.002309083938599 seconds
# Making matcha..................
# Matcha is ready!................,,,,,,,,,,,,,,,,
# Task time: 2.0097239017486572 seconds

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

# %%
def timer_dec(base_fn):
    def enhanced_fn(*args , **kwargs):
        start_time = time.time()
        base_fn(*args , **kwargs)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} seconds")
    return enhanced_fn

@timer_dec
def brew_tea(tea_type , steep_time):
    print("Brewing tea .......")
    time.sleep(5)
    print("tea is ready.......................")
    
@timer_dec
def make_matcha():
    print("Making matcha..................")
    time.sleep(2)
    print("Matcha is ready!................,,,,,,,,,,,,,,,,")


make_matcha()
# Out:
# Making matcha..................
# Matcha is ready!................,,,,,,,,,,,,,,,,
# Task time: 2.0012800693511963 seconds
