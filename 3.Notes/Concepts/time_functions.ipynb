# %%
from time import time

# %%
start = time()

[n**2 for n in range(1,100000001)]

end = time()

print('list comp run time: ', end - start)
# Out:
# list comp run time:  6.816272497177124

# %%
from time import time

# %%
start = time()

[n**2 for n in range(1,101)]

end = time()

print('list comp run time: ', end - start)
# Out:
# list comp run time:  6.031990051269531e-05

# %%
start = time()

[n**2 for n in range(1,1001)]

end = time()

print("Start time is : ", start)
print("End time is the time: ", end)

print('list comp run time: ', end - start)
# Out:
# Start time is :  1767283956.2872064
# End time is the time:  1767283956.287329
# list comp run time:  0.00012254714965820312

# %%
from time import time

# %%
start = time()
squares = []

for n in range(1 , 100000001):
    squares.append(n**2)
end = time()

print("Start time is : ", start)
print("End time is the time: ", end)

print("Loop + append run time: ", end - start)
# Out:
# Start time is :  1767284106.9765377
# End time is the time:  1767284116.5210626
# Loop + append run time:  9.544524908065796
